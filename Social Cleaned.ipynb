# %% [markdown]
# # Social Media DataSet Cleaning

# %%
import pandas as pd

# %%
df1 = pd.read_excel(r'C:\Users\ANUSHA\Downloads\social_Media.xlsx',sheet_name='data')
df2 = pd.read_excel(r'C:\Users\ANUSHA\Downloads\social_Media.xlsx', sheet_name='interaction')

# %%
df1
# Out:
#            ID   Platform                               Post ID Post Type  \
# 0           2   LinkedIn  d49dadb4-fc1e-4775-88ad-d60b75cf5123     Video
# 1           3  Instagram  16ce29c5-2dc7-478f-9814-a86754f3ce8b     Video
# 2           4  Instagram  6a6cc741-72f4-4111-95a0-c5ee04a175a8     Video
# 3           5    Twitter  0b5a3e70-c556-43cb-ad4f-a1d0003348bc     Image
# 4           6   Facebook  a7d3e958-e2fe-411e-a24a-b96e821fc050      Link
# ...       ...        ...                                   ...       ...
# 99995   99997   LinkedIn  26534a4f-0cb6-4bb3-b852-d1cadc15584e      Link
# 99996   99998   Facebook  df9577d4-9338-4f41-99f9-8e8f1e34febd      Link
# 99997   99999   LinkedIn  43cd806e-704b-4718-9924-2555c189f8b2      Link
# 99998  100000  Instagram  3485970a-0f34-4304-a60a-f4e3de8e1917      Link
# 99999  100001    Twitter  6b1406b0-adca-43e5-abde-799746a9b50a      Link
#
#                                             Post Content  \
# ...

# %%
df2.head()
# Out:
#    ID   Platform                               Post ID Post Type  \
# 0   2  Instagram  16ce29c5-2dc7-478f-9814-a86754f3ce8b     Video
# 1   3   Facebook  a30c948b-0fb3-4e92-95da-e2dea184f568      Link
# 2   4    Twitter  aee74d06-c775-459c-8fc4-013ce25644f1     Image
# 3   5  Instagram  80415748-a509-4fc6-8b55-74f2babe5dac     Image
# 4   6   LinkedIn  14d34185-639a-4508-a8b6-02a743fe0dbc      Link
#
#                                        Post Content          Post Timestamp  \
# 0                      Increase fast partner south. 2023-07-30 06:40:06.356
# 1           Floor glass bring indicate seem detail. 2022-06-19 14:15:59.833
# 2  Customer stop language everybody rest chance me. 2022-06-04 06:19:50.403
# 3                     Town find identify game your. 2022-05-12 15:41:21.902
# 4                            Seem strategy you cup. 2023-10-26 20:53:33.135
#
#         Date Weekday Type                    Time Time Periods  ...  \
# ...

# %%
len(df1)
# Out:
# 100000

# %%
df1.isnull().sum()
# Out:
# ID                        0
# Platform                  0
# Post ID                   0
# Post Type                 0
# Post Content              0
# Post Timestamp            0
# Likes                     0
# Comments                  0
# Shares                    0
# Impressions               0
# Reach                     0
# Engagement Rate           0
# Audience Age              0
# Audience Gender           0
# Audience Location         0
# Audience Interests        0
# Campaign ID           79868
# Sentiment             50100
# Influencer ID         90006
# dtype: int64

# %%
df2.isnull().sum()
# Out:
# ID                        0
# Platform                  0
# Post ID                   0
# Post Type                 0
# Post Content              0
# Post Timestamp            0
# Date                      0
# Weekday Type              0
# Time                      0
# Time Periods              0
# Likes                     0
# Comments                  0
# Shares                    0
# Impressions               0
# Reach                     0
# Engagement Rate           0
# Audience Age              0
# Age Group                 0
# Audience Gender           0
# Audience Location         0
# Audience Continent        0
# Audience Interests        0
# Campaign ID           79868
# Sentiment                 0
# Influencer ID         90006
# dtype: int64

# %%
df1.drop_duplicates(inplace=True)

# %%
df1.isnull().sum()
# Out:
# ID                        0
# Platform                  0
# Post ID                   0
# Post Type                 0
# Post Content              0
# Post Timestamp            0
# Likes                     0
# Comments                  0
# Shares                    0
# Impressions               0
# Reach                     0
# Engagement Rate           0
# Audience Age              0
# Audience Gender           0
# Audience Location         0
# Audience Interests        0
# Campaign ID           79868
# Sentiment             50100
# Influencer ID         90006
# dtype: int64

# %%
df2.drop_duplicates(inplace=True)

# %%
df2.isnull().sum()
# Out:
# ID                        0
# Platform                  0
# Post ID                   0
# Post Type                 0
# Post Content              0
# Post Timestamp            0
# Date                      0
# Weekday Type              0
# Time                      0
# Time Periods              0
# Likes                     0
# Comments                  0
# Shares                    0
# Impressions               0
# Reach                     0
# Engagement Rate           0
# Audience Age              0
# Age Group                 0
# Audience Gender           0
# Audience Location         0
# Audience Continent        0
# Audience Interests        0
# Campaign ID           79868
# Sentiment                 0
# Influencer ID         90006
# dtype: int64

# %%
df2.isnull().sum()
# Out:
# ID                        0
# Platform                  0
# Post ID                   0
# Post Type                 0
# Post Content              0
# Post Timestamp            0
# Date                      0
# Weekday Type              0
# Time                      0
# Time Periods              0
# Likes                     0
# Comments                  0
# Shares                    0
# Impressions               0
# Reach                     0
# Engagement Rate           0
# Audience Age              0
# Age Group                 0
# Audience Gender           0
# Audience Location         0
# Audience Continent        0
# Audience Interests        0
# Campaign ID           79868
# Sentiment                 0
# Influencer ID         90006
# dtype: int64

# %%
df1
# Out:
#            ID   Platform                               Post ID Post Type  \
# 0           2   LinkedIn  d49dadb4-fc1e-4775-88ad-d60b75cf5123     Video
# 1           3  Instagram  16ce29c5-2dc7-478f-9814-a86754f3ce8b     Video
# 2           4  Instagram  6a6cc741-72f4-4111-95a0-c5ee04a175a8     Video
# 3           5    Twitter  0b5a3e70-c556-43cb-ad4f-a1d0003348bc     Image
# 4           6   Facebook  a7d3e958-e2fe-411e-a24a-b96e821fc050      Link
# ...       ...        ...                                   ...       ...
# 99995   99997   LinkedIn  26534a4f-0cb6-4bb3-b852-d1cadc15584e      Link
# 99996   99998   Facebook  df9577d4-9338-4f41-99f9-8e8f1e34febd      Link
# 99997   99999   LinkedIn  43cd806e-704b-4718-9924-2555c189f8b2      Link
# 99998  100000  Instagram  3485970a-0f34-4304-a60a-f4e3de8e1917      Link
# 99999  100001    Twitter  6b1406b0-adca-43e5-abde-799746a9b50a      Link
#
#                                             Post Content  \
# ...

# %%
df2
# Out:
#            ID   Platform                               Post ID Post Type  \
# 0           2  Instagram  16ce29c5-2dc7-478f-9814-a86754f3ce8b     Video
# 1           3   Facebook  a30c948b-0fb3-4e92-95da-e2dea184f568      Link
# 2           4    Twitter  aee74d06-c775-459c-8fc4-013ce25644f1     Image
# 3           5  Instagram  80415748-a509-4fc6-8b55-74f2babe5dac     Image
# 4           6   LinkedIn  14d34185-639a-4508-a8b6-02a743fe0dbc      Link
# ...       ...        ...                                   ...       ...
# 99995   99997   Facebook  bfc611aa-71e3-462d-a200-c671b5f2dd45     Video
# 99996   99998   LinkedIn  26534a4f-0cb6-4bb3-b852-d1cadc15584e      Link
# 99997   99999   Facebook  df9577d4-9338-4f41-99f9-8e8f1e34febd      Link
# 99998  100000   LinkedIn  43cd806e-704b-4718-9924-2555c189f8b2      Link
# 99999  100001  Instagram  3485970a-0f34-4304-a60a-f4e3de8e1917      Link
#
#                                            Post Content  \
# ...

# %%
SM = pd.merge(df1, df2, on='ID', how='inner')

# %%
SM
# Out:
#            ID Platform_x                             Post ID_x Post Type_x  \
# 0           2   LinkedIn  d49dadb4-fc1e-4775-88ad-d60b75cf5123       Video
# 1           3  Instagram  16ce29c5-2dc7-478f-9814-a86754f3ce8b       Video
# 2           4  Instagram  6a6cc741-72f4-4111-95a0-c5ee04a175a8       Video
# 3           5    Twitter  0b5a3e70-c556-43cb-ad4f-a1d0003348bc       Image
# 4           6   Facebook  a7d3e958-e2fe-411e-a24a-b96e821fc050        Link
# ...       ...        ...                                   ...         ...
# 99995   99997   LinkedIn  26534a4f-0cb6-4bb3-b852-d1cadc15584e        Link
# 99996   99998   Facebook  df9577d4-9338-4f41-99f9-8e8f1e34febd        Link
# 99997   99999   LinkedIn  43cd806e-704b-4718-9924-2555c189f8b2        Link
# 99998  100000  Instagram  3485970a-0f34-4304-a60a-f4e3de8e1917        Link
# 99999  100001    Twitter  6b1406b0-adca-43e5-abde-799746a9b50a        Link
#
#                                           Post Content_x  \
# ...

# %%
SM.to_csv('Social.csv', index=False)
